# %%
import jwt
import datetime

# %%
validity = datetime.datetime.now() + datetime.timedelta(days=90)

# %%
encode= jwt.encode({'username':"Mangesh" , 'exp':validity } , key="" , algorithm='HS256')
encode
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6Ik1hbmdlc2giLCJleHAiOjE3NDgxOTA0NTN9.lC4AJuaQNYUPiFz1FzoHovfWS-2YQs_dEOpuUMyGF20'

# %%
encode='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6Ik1hbmdlc2giLCJQYXNzd29yZCI6IlNhdGhlIiwiZXhwIjoxNzQzMzQ2NjAwfQ.m_35Xt-7sBvBxu9e29FnJqebIe61wk2-51lwV3fqjts'

# %%
user_name=jwt.decode(encode , key='', algorithms=['HS256'])
user_name
# Out:
# {'username': 'Mangesh', 'Password': 'Sathe', 'exp': 1743346600}
